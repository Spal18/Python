# %% [markdown]
# <a href="https://colab.research.google.com/github/Spal18/Python/blob/main/Data_Toolkit_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.Demonstrate three different methods for creating identical 2D arrays in NumPy Provide the code for each method and the final output after each method ?
#Ans. Here are three different methods to create identical 2D arrays in NumPy:

#Method 1: Using np.array()
import numpy as np

arr1 = np.array([[1, 2, 3], [4, 5, 6]])
print(arr1)

#Method 2: Using np.zeros()
arr2 = np.zeros((2, 3))
print(arr2)

#Method 3: Using np.reshape()
arr3 = np.arange(6).reshape((2, 3))
print(arr3)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[0. 0. 0.]
#  [0. 0. 0.]]
# [[0 1 2]
#  [3 4 5]]

# %%
#2. Using the Numpy function, generate an array of wRR evenly spaced numbers between w and wR and reshape that wD array into a 2D array.
#Ans. To generate an array of wRR evenly spaced numbers between w and wR using NumPy, and then reshape it into a 2D array, you can use the numpy.linspace function followed by the reshape method.
import numpy as np

# Define the parameters
w = 0
wR = 1000
wRR = 20
wD = 4

# Generate the array of evenly spaced numbers
array = np.linspace(w, wR, wRR)

# Reshape the array into a 2D array
reshaped_array = array.reshape(wD, -1)

print(reshaped_array)
# Out:
# [[   0.           52.63157895  105.26315789  157.89473684  210.52631579]
#  [ 263.15789474  315.78947368  368.42105263  421.05263158  473.68421053]
#  [ 526.31578947  578.94736842  631.57894737  684.21052632  736.84210526]
#  [ 789.47368421  842.10526316  894.73684211  947.36842105 1000.        ]]

# %%
#3. Explain the following terms:
#a. The difference in np.array, np.asarray and np.asanyarray.
#Ans.import numpy as np

# creating array
a = np.array([ 2, 3, 4, 5, 6])
print("Original array : ",a)

# assigning value to np.array
np_array = np.array(a)
a[3] = 0
print("np.array Array : ",np_array)

# assigning value to np.asarray
np_array = np.asarray(a)
print("np.asarray Array : ",np_array)


#B. The difference between Deep copy and shallow copy.
import copy

original = [1, [2, 3], 4]

# Shallow Copy
shallow_copy = copy.copy(original)
shallow_copy[1][0] = 'Changed'
print("Original:", original)  # Output: [1, ['Changed', 3], 4]
print("Shallow Copy:", shallow_copy)  # Output: [1, ['Changed', 3], 4]

# Deep Copy
deep_copy = copy.deepcopy(original)
deep_copy[1][0] = 'Deep Changed'
print("Original:", original)  # Output: [1, ['Changed', 3], 4]
print("Deep Copy:", deep_copy)  # Output: [1, ['Deep Changed', 3], 4]
# Out:
# Original array :  [2 3 4 5 6]
# np.array Array :  [2 3 4 5 6]
# np.asarray Array :  [2 3 4 0 6]
# Original: [1, ['Changed', 3], 4]
# Shallow Copy: [1, ['Changed', 3], 4]
# Original: [1, ['Changed', 3], 4]
# Deep Copy: [1, ['Deep Changed', 3], 4]

# %%
#4. Generate a 3*3 array with random floating-point numPers between 5 and 20. Then, round each number in the array to 2 decimal places?
#Ans.

import numpy as np

# Generate a 3x3 array with random floating-point numbers between 5 and 20
array = np.random.uniform(5, 20, (3, 3))

# Round each number in the array to 2 decimal places
rounded_array = np.round(array, 2)

print("Original array:\n", array)
print("Rounded array:\n", rounded_array)
# Out:
# Original array:
#  [[12.72751695  5.22421959  6.08465872]
#  [13.50544699 14.31536278 16.78150884]
#  [11.91830252 19.01095017 15.98419263]]
# Rounded array:
#  [[12.73  5.22  6.08]
#  [13.51 14.32 16.78]
#  [11.92 19.01 15.98]]

# %%
#5.Create a NumPy array with random integers between 1 and 10 of shape (5,6 ). After creating the array perform the following operations:
#a)Extract all even integers from array.
array=np.random.randint(1,10,(5,6))
print(array)

#b)Extract all odd integers from array.
print(array[array%2!=0])

import numpy as np

# Create a NumPy array with random integers between 1 and 10 of shape (5, 6)
array = np.random.randint(1, 10, size=(5, 6))
print("Original Array:\n", array)

# Operation 1: Find the sum of all elements
sum_all_elements = np.sum(array)
print("Sum of all elements:", sum_all_elements)

# Operation 2: Find the mean of all elements
mean_all_elements = np.mean(array)
print("Mean of all elements:", mean_all_elements)

# Operation 3: Find the maximum value in the array
max_value = np.max(array)
print("Maximum value in the array:", max_value)

# Operation 4: Find the minimum value in the array
min_value = np.min(array)
print("Minimum value in the array:", min_value)

# Operation 5: Find the standard deviation of the elements
std_deviation = np.std(array)
print("Standard deviation of the elements:", std_deviation)
# Out:
# [[8 4 1 4 3 3]
#  [3 9 7 2 7 3]
#  [6 3 6 1 6 7]
#  [2 9 3 2 3 8]
#  [8 6 4 5 4 3]]
# [1 3 3 3 9 7 7 3 3 1 7 9 3 3 5 3]
# Original Array:
#  [[1 4 1 6 7 7]
#  [7 6 5 3 3 2]
#  [8 6 8 7 7 8]
#  [1 8 2 7 2 6]
#  [6 1 6 6 9 3]]
# Sum of all elements: 153
# Mean of all elements: 5.1
# Maximum value in the array: 9
# Minimum value in the array: 1
# Standard deviation of the elements: 2.4946609656090213

# %%
# 6. Create a 3D NumPy array of shape (3,3,3) containing random integers between 1 and 10.Perform the following operations:
# a) Find the indices of the maximum values along each depth level (third axis).
# b) Perform elementwise multiplication of between both array

array_3d = np.random.randint(1, 11, size=(3, 3, 3))
print("\nOriginal 3D Array:\n", array_3d)

max_indices_along_depth = np.argmax(array_3d, axis=2)
print("Indices of maximum values along each depth level:\n", max_indices_along_depth)

# Assuming you want to multiply the array by itself
multiplied_array = np.multiply(array_3d, array_3d)
print("Elementwise multiplication of array with itself:\n", multiplied_array)
# Out:
# Original 3D Array:
#  [[[ 3  3  8]
#   [ 4 10  9]
#   [ 8  8  9]]
#
#  [[ 2  9  8]
#   [ 1  2  1]
#   [ 6 10  4]]
#
#  [[ 3  4  8]
#   [ 5  2  3]
#   [ 8  6  6]]]
# Indices of maximum values along each depth level:
#  [[2 1 2]
#  [1 1 1]
#  [2 0 0]]
# Elementwise multiplication of array with itself:
#  [[[  9   9  64]
#   [ 16 100  81]
#   [ 64  64  81]]
#
#  [[  4  81  64]
#   [  1   4   1]
#   [ 36 100  16]]
#
#  [[  9  16  64]
#   [ 25   4   9]
#   [ 64  36  36]]]

# %%
#7.Clean and transform the 'Phone' column in the sample dataset to remove non-numeric characters and convert it to a numeric data type. Also display the table attributes and data types of each column.
 #  https://drive.google.com/file/d/13x8f8HNKieSRAzxTIzAojaYp8Up8cefk/view



# Assuming you have a DataFrame named 'df' with a 'Phone' column
# Replace 'your_file.csv' with the actual path to your CSV file
# df = pd.read_csv('your_file.csv')

# Sample DataFrame
data = {'Phone': ['(123) 456-7890', '555-1234', '1-800-555-1212', 'abc123', '987-6543']}
df = pd.DataFrame(data)

# Remove non-numeric characters and convert to numeric
df['Phone'] = df['Phone'].str.replace(r'\D', '', regex=True)
df['Phone'] = pd.to_numeric(df['Phone'], errors='coerce')

# Display table attributes and data types
print(df.info())

# Print the updated DataFrame
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Phone   5 non-null      int64
# dtypes: int64(1)
# memory usage: 168.0 bytes
# None
#          Phone
# 0   1234567890
# 1      5551234
# 2  18005551212
# 3          123
# 4      9876543

# %%
#8. Perform the following tasks using people dataset:
#a) Read the 'data.csv' file using pandas, skipping the first 50 rows.
import pandas as pd

# Replace with the actual file ID from your Google Drive link
file_id = '13x8f8HNKieSRAzxTIzAojaYp8Up8cefk'

# Construct the correct URL for downloading the CSV file
url = f'https://drive.google.com/uc?id={file_id}&export=download'

# Read the CSV file from the URL, skipping the first 50 rows
df = pd.read_csv(url, skiprows=50)

# Display the first few rows of the dataframe to verify
print(df.head())

#b) Only read the columns: 'Last Name', ‘Gender’,’Email’,‘Phone’ and ‘Salary’ from the file.

# Read the CSV file from the URL, selecting specific columns
df = pd.read_csv(url, usecols=['Last Name', 'Gender', 'Email', 'Phone', 'Salary'])

print(df)

#c) Display the first 10 rows of the filtered dataset.

import pandas as pd

# Assuming 'df' is your original DataFrame
filtered_df = df[df['Gender'] == 'Male']  # Apply your filter condition using an actual column name
print(filtered_df.head(10))  # Display the first 10 rows


#d) Extract the ‘Salary’' column as a Series and display its last 5 values.

import pandas as pd

# Assuming you have a DataFrame named df
# Extract the 'Salary' column as a Series
salary_series = df['Salary']

# Display the last 5 values
print(salary_series.tail(5))
# Out:
#    50  afF3018e9cdd1dA     George  Mercer  Female  \
# 0  51  CccE5DAb6E288e5         Jo  Zavala    Male
# 1  52  DfBDc3621D4bcec     Joshua   Carey  Female
# 2  53  f55b0A249f5E44D     Rickey   Hobbs  Female
# 3  54  Ed71DcfaBFd0beE      Robyn  Reilly    Male
# 4  55  FDaFD0c3f5387EC  Christina  Conrad    Male
#
#   douglascontreras@example.net    +1-326-669-0118x4341  11-09-1941  \
# 0         pamela64@example.net  001-859-448-9935x54536  23-11-1992
# 1    dianashepherd@example.net    001-274-739-8470x814  07-01-1915
# 2    ingramtiffany@example.org        241.179.9509x498  01-07-1910
# 3   carriecrawford@example.org       207.797.8345x6177  27-07-1982
# 4   fuentesclaudia@example.net    001-599-042-7428x143  06-01-1998
#
#   Human resources officer   70000
# 0            Nurse, adult   80000
# 1     Seismic interpreter   70000
# 2               Barrister   60000
# 3    Engineer, structural  100000
# 4         Producer, radio   50000
# ...

# %%
#9. Filter and select rows from the People_Dataset, where the “Last Name' column contains the name 'Duke', 'Gender' column contains the word Female and ‘salary’ should be less than 850000.
import pandas as pd

# Replace with the actual file ID from your Google Drive link
file_id = '13x8f8HNKieSRAzxTIzAojaYp8Up8cefk'

# Construct the correct URL for downloading the CSV file
url = f'https://drive.google.com/uc?id={file_id}&export=download'

# Assuming your dataset is in a CSV file
df = pd.read_csv(url) # Use the correct URL for downloading the file

# Applying the filter conditions
filtered_df = df[(df['Last Name'].str.contains('Duke')) &
                 (df['Gender'].str.contains('Female')) &
                 (df['Salary'] < 850000)]

# Display the filtered DataFrame
print(filtered_df)
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 45      46  99A502C175C4EBd     Olivia      Duke  Female
# 210    211  DF17975CC0a0373    Katrina      Duke  Female
# 457    458  dcE1B7DE83c1076      Traci      Duke  Female
# 729    730  c9b482D7aa3e682     Lonnie      Duke  Female
#
#                         Email                   Phone Date of birth  \
# 45        diana26@example.net  001-366-475-8607x04350    13-10-1934
# 210       robin78@example.com            740.434.0212    21-09-1935
# 457  perryhoffman@example.org     +1-903-596-0995x489    11-02-1997
# 729   kevinkramer@example.net            982.692.6257    12-05-2015
#
#            Job Title  Salary
# 45           Dentist   60000
# 210  Producer, radio   50000
# 457        Herbalist   50000
# 729     Nurse, adult   70000

# %%
#10. Create a 7*5 Dataframe in Pandas using a series generated from 35. random integers between 1 to 6?
# Replace with the actual file ID from your Google Drive link
#file_id = '13x8f8HNKieSRAzxTIzAojaYp8Up8cefk'
import pandas as pd
import numpy as np

# Generate a series of 35 random integers between 1 and 6
random_integers = np.random.randint(1, 7, size=35)

# Reshape the series into a 7x5 DataFrame
df = pd.DataFrame(random_integers.reshape(7, 5))

print(df)
# Out:
#    0  1  2  3  4
# 0  5  3  6  1  2
# 1  2  2  1  1  3
# 2  2  2  6  6  3
# 3  5  4  1  2  4
# 4  2  1  5  2  3
# 5  1  1  6  5  1
# 6  4  2  6  1  3

# %%
#11. Create two different Series, each of length 50, with the following criteria:
# Replace with the actual file ID from your Google Drive link
#file_id = '13x8f8HNKieSRAzxTIzAojaYp8Up8cefk'

#a) The first Series should contain random numbers ranging from 10 to 50.
import numpy as np

# Generate a series of 10 random numbers between 10 and 50
random_series = np.random.randint(10, 51, size=10)
print(random_series)

#b) The second Series should contain random numbers ranging from 100 to 1000
import pandas as pd
import numpy as np

# Generate a Series with random numbers ranging from 100 to 1000
random_series = pd.Series(np.random.randint(100, 1001, size=10))

print(random_series)

#c) Create a DataFrame by joining these Series by column, and, change the names of the columns to 'col1', 'col2', etc.

import pandas as pd

# Sample Series
series1 = pd.Series([1, 2, 3])
series2 = pd.Series([4, 5, 6])
series3 = pd.Series([7, 8, 9])

# Create a DataFrame by joining the Series
df = pd.concat([series1, series2, series3], axis=1)

# Rename the columns
df.columns = ['col1', 'col2', 'col3']

print(df)
# Out:
# [40 21 34 28 30 19 33 50 12 19]
# 0    464
# 1    650
# 2    815
# 3    780
# 4    610
# 5    507
# 6    745
# 7    873
# 8    175
# 9    707
# dtype: int64
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
#12. Perform the following operations using people data set:

#a) Delete the 'Email', 'Phone', and 'Date of birth' columns from the dataset
#b) Delete the rows containing any missing values.
#d) Print the final output also.

import pandas as pd

# Load your dataset
# Make sure the path to your file is correct. If unsure, you can list files in the current directory using !ls
df = pd.read_csv('data.csv')

# a) Delete the 'Email', 'Phone', and 'Date of birth' columns
df.drop(columns=['Email', 'Phone', 'Date of birth'], inplace=True)

# b) Delete the rows containing any missing values
df.dropna(inplace=True)

# d) Print the final output
print(df)
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                            Job Title  Salary
# 0                  Probation officer   90000
# 1                             Dancer   80000
# 2                               Copy   50000
# 3           Counselling psychologist   65000
# 4                Biomedical engineer  100000
# ...

# %%
# 13. Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the  following tasks using Matplotlib and NumPy:
# a) Create a scatter Plot using x and y, setting the color of the Points to red and the marker style to 'o'.
# b) Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.
# c) Add a vertical line at x = 0.5 using a dotted lin

import numpy as np
import matplotlib.pyplot as plt

# Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1.
x = np.random.rand(100)
y = np.random.rand(100)

# Create a scatter plot using x and y
plt.scatter(x, y, color='GREEN', marker='o')

# Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.
plt.axhline(y=0.5, linestyle='--', label='y = 0.5')

# Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.
plt.axvline(x=0.5, linestyle=':', label='x = 0.5')

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()

# %%
#14.  Create  a time-series dataset  in a Pandas DataFrame with columns: 'Date', 'Temperature', 'Humidity' and Perform the following tasks using Matplotlib:
# a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes (left y-axis for 'Temperature' and right y-axis for 'Humidity').
# b) Label the x-axis as 'Date'.
# c) Set the title of the plot as 'Temperature and Humidity Over Time'.

import pandas as pd
import matplotlib.pyplot as plt

# Create a time-series dataset
date_range = pd.date_range(start='2023-10-26', periods=30)
temperature = [20 + i * 0.5 for i in range(30)]
humidity = [60 + i * 0.2 for i in range(30)]

data = {'Date': date_range, 'Temperature': temperature, 'Humidity': humidity}
df = pd.DataFrame(data)

# Create the plot with two y-axes
fig, ax1 = plt.subplots()

# Plot Temperature on the left y-axis
color = 'tab:red'
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color=color)
ax1.plot(df['Date'], df['Temperature'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for Humidity
ax2 = ax1.twinx()  # Create a second axes that shares the same x-axis

# Plot Humidity on the right y-axis
color = 'tab:blue'
ax2.set_ylabel('Humidity (%)', color=color)
ax2.plot(df['Date'], df['Humidity'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Set the title of the plot
plt.title('Temperature and Humidity Over Time')

# Display the plot
plt.show()

# %%
# 15.  Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following tasks using Matplotlib:
# a) Plot a histogram of the data with 30 bins.
# b) Overlay a line plot representing the normal distribution's probability density function (PDF).
# c) Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'.
# d) Set the title of the plot as 'Histogram with PDF Overl

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Create a NumPy array with 1000 samples from a normal distribution
data = np.random.normal(loc=0, scale=1, size=1000)

# Plot a histogram of the data with 30 bins
plt.hist(data, bins=30, density=True, alpha=0.6, color='y')

# Overlay a line plot representing the normal distribution's PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, loc=0, scale=1)
plt.plot(x, p, 'k', linewidth=2)

# Label the x-axis and y-axis
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

# Set the title of the plot
plt.title('Histogram with PDF Overlay')

# Display the plot
plt.show()

# %%
#16. Set the title of the plot as 'Histogram with PDF Overlay'.

import matplotlib.pyplot as plt
# Set the title of the plot
plt.title('Histogram with PDF Overlay')
# Out:
# Text(0.5, 1.0, 'Histogram with PDF Overlay')

# %%
#17.Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot'.

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Create two random arrays
x = np.random.randn(1000)
y = np.random.randn(1000)

# Determine quadrant for each point
quadrant = np.where(x >= 0, np.where(y >= 0, 'Q1', 'Q4'), np.where(y >= 0, 'Q2', 'Q3'))

# Create a scatter plot with Seaborn, coloring points by quadrant
sns.scatterplot(x=x, y=y, hue=quadrant)

# Add a legend
plt.legend()

# Label the axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Set the title
plt.title('Quadrant-wise Scatter Plot')

# Show the plot
plt.show()

# %%
#18. With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine Wave Function'.

# !pip install bokeh

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
import numpy as np

output_notebook()

# Create data for the sine wave
x = np.linspace(0, 2 * np.pi, 1000)
y = np.sin(x)

# Create a figure
p = figure(title="Sine Wave Function", x_axis_label="x", y_axis_label="sin(x)")

# Add a line glyph
p.line(x, y, line_width=2)

# Add grid lines
p.grid.grid_line_alpha = 0.3

# Show the plot
show(p)
# Out:
# ...
#   <div id="fef1cd4c-ee48-41e8-8837-196194877509" data-root-id="p1089" style="display: contents;"></div>

# %%
#19. Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their values, add hover tooltips to display exact values, label the axes, and set the title as 'Random Categorical Bar Chart'.
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import HoverTool, LinearColorMapper
import numpy as np

output_notebook()

# Generate random categorical data
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(1, 20, size=len(categories))

# Create a color mapper to map values to colors
color_mapper = LinearColorMapper(palette="Viridis256", low=min(values), high=max(values))

# Create a figure
p = figure(title="Random Categorical Bar Chart", x_axis_label="Category", y_axis_label="Value")

# Add a bar glyph with color mapped from values
bars = p.vbar(x=categories, top=values, width=0.5, color={'field': 'top', 'transform': color_mapper}, legend_label="Values")

# Add hover tooltips to display exact values
hover = HoverTool(tooltips=[("Category", "@x"), ("Value", "@top")], renderers=[bars])
p.add_tools(hover)

# Show the plot
show(p)
# Out:
#   <div id="e52914c7-44f9-4da7-b1af-949d3e306a92" data-root-id="p1217" style="display: contents;"></div>

# %%
#20. Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as 'Simple Line Plot'.

# !pip install plotly

import plotly.graph_objects as go
import numpy as np

# Generate random data
x = np.arange(10)
y = np.random.rand(10)

# Create a line plot using Plotly
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='lines'))

# Set axis labels and title
fig.update_layout(
    xaxis_title='X-axis',
    yaxis_title='Y-axis',
    title='Simple Line Plot'
)

# Show the plot
fig.show()
# Out:
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#21. Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set the title as 'Interactive Pie Chart'.

# !pip install plotly

import plotly.graph_objects as go
import numpy as np

# Generate random data
labels = ['Category A', 'Category B', 'Category C', 'Category D']
values = np.random.randint(1, 100, size=len(labels))

# Create an interactive pie chart using Plotly
fig = go.Figure(data=[go.Pie(labels=labels, values=values)])

# Customize the chart
fig.update_layout(
    title='Interactive Pie Chart',
    showlegend=True
)

# Show the chart
fig.show()
# Out:
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
